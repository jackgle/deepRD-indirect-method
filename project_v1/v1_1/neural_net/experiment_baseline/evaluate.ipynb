# %%
import os
os.sys.path.append('../lib/')
import numpy as np
import evaluate

# load test predictions and labels
files_test = np.load('./data/files_test.npy')
p_test = np.load('./nn_output/model_test_p_scaled.npy')
y_test = np.load('./nn_output/model_test_y_scaled.npy')

evaluate.full_evaluation(p_test, y_test, files_test)
# Out:
# Number of samples per analyte in test set
# Ca      76
# LDH     72
# GGT     64
# IgE     60
# LACT    60
# FT4     60
# CRP     48
# AST     48
# Hb      44
# TSH     36
# Name: an, dtype: int64
#
# Example predictions
# Error per analyte
# IgE  -  0.1  z-score dev. nan's
#   analyte  zscore_dev  norm_errors
# 0      Hb    0.127439     0.065021
# 1      Ca    0.131602     0.067230
# 2     FT4    0.079975     0.041408
# 3     AST    0.087647     0.045833
# 4    LACT    0.066470     0.032434
# 5     GGT    0.082373     0.050432
# 6     TSH    0.140741     0.051796
# 7     IgE    0.261974     0.090967
# 8     CRP    0.048597     0.173195
# 9     LDH    0.115784     0.054107
# Average z-score deviation:	 0.11426016856522869
# Average norm. error:		 0.06724228191350384
#
# Error per skew group
# ['TSH', 'IgE']  -  0.062  z-score dev. nan's
#                 group  zscore_dev  norm_errors
# 0              normal    0.113375     0.058082
# 1              skewed    0.078297     0.042870
# ...
