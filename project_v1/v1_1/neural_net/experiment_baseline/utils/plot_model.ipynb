# %% [markdown]
# This notebook creates a visualization of the neural network model's architecture.

# %%
# !pip install pydot
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pydot) (3.1.1)
# Requirement already satisfied: graphviz in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (0.20.1)

# %%
import tensorflow as tf

# define model
inputs = tf.keras.layers.Input(shape=(500,))
x = tf.keras.layers.Dense(512, activation='relu')(inputs)
x = tf.keras.layers.Dense(512, activation='relu')(x)
x = tf.keras.layers.Dense(512, activation='relu')(x)
o = tf.keras.layers.Dense(2, activation='linear')(x)
model = tf.keras.models.Model(inputs, o)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 500)]             0
#
#  dense (Dense)               (None, 512)               256512
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 782850 (2.99 MB)
# Trainable params: 782850 (2.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-20 10:48:34.414603: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=False,
)
