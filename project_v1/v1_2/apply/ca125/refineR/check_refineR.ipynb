# %%
# install.packages('refineR')

# %%
library(refineR)

# %%
file = '../data/age_binned/data_85.csv'
data <- read.csv(file)$value # read simulated values

# %%
length(data)
# Out:
# [1] 209

# %%
fit <- findRI(data, model='BoxCox') # use refineR to get model fit
# Out:
#  Data has small sample size (N < 1000). Evaluate results carefully.

# %%
fit
# Out:
# Reference Intervals
# ------------------------------------------------
# lower limit [ 2.5% perc]: 3.6
# upper limit [97.5% perc]: 34.4
#
# Model Parameters
# ------------------------------------------------
#      method: refineR (v1.6.1)
#       model: BoxCox
#      N data: 209
#     rounded: yes (base: 0.05)
#   point est: fullDataEst
#      lambda: 0.033
#          mu: 2.53
#       sigma: 0.623
#       shift: 0
#        cost: -7.02
# NP fraction: 0.885

# %%
hist(data, 100)
# Out:
# Plot with title “Histogram of data”

# %%
plot(fit, xlim=c(0, 100))
# Out:
# Plot with title “Estimated Reference Interval”

# %%
result <- getRI(fit, Scale='original') # get RI estimate from model
result
# Out:
#   Percentile PointEst  CILow CIHigh
# 1 0.025       3.599782 NA    NA
# 2 0.975      34.375278 NA    NA
