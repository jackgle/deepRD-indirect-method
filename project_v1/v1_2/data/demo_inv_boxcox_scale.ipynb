# %%
import numpy as np
from scipy.special import inv_boxcox
import matplotlib.pyplot as plt

sample1 = np.random.normal(3, 1, 5000)
sample2 = np.random.normal(10, 1, 5000)

# %%
plt.hist(inv_boxcox(sample1, 0.2), 50);

# %%
plt.hist(inv_boxcox(sample2, 0.2), 50);
