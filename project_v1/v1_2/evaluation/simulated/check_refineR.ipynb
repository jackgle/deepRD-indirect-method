# %%
# install.packages('refineR')

# %%
library(refineR)

dr = './test_csvs/'

# set.seed(123) # random seed for shuffling

# %%
file = '878.csv'
file = '459.csv'
data <- read.csv(paste0(dr,file), header=FALSE)$V1 # read simulated values

# %%
length(data)
# Out:
# [1] 4999

# %%
fit <- findRI(data, model='modBoxCox') # use refineR to get model fit

# %%
fit
# Out:
# Reference Intervals
# ------------------------------------------------
# lower limit [ 2.5% perc]: NA
# upper limit [97.5% perc]: NA
#
# Model Parameters
# ------------------------------------------------
#      method: refineR (v1.6.1)
#       model: modBoxCox
#      N data: 4999
#     rounded: yes (base: 0.05)
#   point est: fullDataEst
#      lambda: NA
#          mu: NA
#       sigma: NA
#       shift: 0
#        cost: 1e+09
# NP fraction: NA

# %%
hist(data, 100)
# Out:
# Plot with title “Histogram of data”

# %%
plot(fit, xlim=c(0, 25))
# Out:
# Plot with title “Estimated Reference Interval”

# %%
result <- getRI(fit, Scale='original') # get RI estimate from model
result
# Out:
#   Percentile PointEst CILow CIHigh
# 1 0.025      NA       NA    NA
# 2 0.975      NA       NA    NA
