# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# define model

inputs = tf.keras.layers.Input(shape=(100, 100, 1))
x = tf.keras.layers.Conv2D(32, kernel_size=10, activation='relu')(inputs)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(64, kernel_size=10, activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(64, kernel_size=10, activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x = tf.keras.layers.Dropout(0.2)(x)
o = tf.keras.layers.Dense(6, activation='linear')(x)
model = tf.keras.models.Model(inputs, o)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 1)]     0
#
#  conv2d (Conv2D)             (None, 91, 91, 32)        3232
#
#  max_pooling2d (MaxPooling2  (None, 45, 45, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 36, 36, 64)        204864
#
#  max_pooling2d_1 (MaxPoolin  (None, 18, 18, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 9, 64)          409664
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 683750 (2.61 MB)
# Trainable params: 683750 (2.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# plot model

# !pip install pydot
# !pip install graphviz
# Out:
# Requirement already satisfied: pydot in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: pyparsing>=3.0.9 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from pydot) (3.1.2)
# Requirement already satisfied: graphviz in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (0.20.3)

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
#     show_dtype=True,
    show_layer_names=False,
#     show_layer_activations=True,
#     rankdir=''
)
